# %%
import numpy as np
from scipy.integrate import odeint
import scipy.interpolate as interp  
import matplotlib.pyplot as plt  
import time   
import  phasediagram as phd
import  singlependulum as sp  
from scipy.interpolate import griddata 
import scipy.ndimage as ndimage 
import seaborn as sns
import matplotlib
from matplotlib import rc

# %%
 #----------simulation time-------
dt_set= 0.05
tLast = 7
tInt = np.arange(0,tLast+dt_set, dt_set) ; 
t = np.linspace(0,dt_set,2) # ---time step per simulation ------  
dtU = 0.001
tU = np.linspace(0,dtU,2) # ---time step per simulation ------   
n_steps = np.int(tLast/dt_set)
print('Number of time steps: '+ str(n_steps) ) 
t_start = time.time()  
 
#-----------child radius----------
rad = dt_set/2.5

#-----------grid size---------- 
y_lim = 10 
x_steps = 120  + 1 
y_steps = 240 + 1
# x_steps = 60  + 1 
# y_steps = 120 + 1

#-----------grid size----------   
x_space = np.linspace(-np.pi,np.pi, x_steps)
y_space = np.linspace(-y_lim,y_lim, y_steps) 
X, Y = np.meshgrid(x_space,y_space) 
 
max_velocity = 10
# ----------physics --------
g = -10
L = 1
mp = 1
Ed = 10 

# ---------controller ------------
R = 100
Q = 1 
u_clip = 3 
n_u = 3  # discretize different control options  
u_opts = np.linspace(-u_clip,u_clip,n_u)


# ---------simulation par  ------------
n_points = 400000  # storage limit   
n_slices = 51    # filter slices 

#----------plotting options ------
intermediate_plotting = False
# intermediate_plotting = True
# Out:
# Number of time steps: 140

# %%
def set_ax_lim(ax_fun): 
    
    xlim = np.pi
    ylim = 9
    
    ax_fun.set_xlim([ -xlim,xlim])
    ax_fun.set_ylim([-ylim,ylim])
    return ax_fun 

def compute_U(J_use,x_space,y_space, X,Y, u_opts, tU,Q,R ) :
    U = np.full( np.shape(J_use), np.nan  )
    Eff = np.full( np.shape(J_use), np.nan  )
    t_start = time.time()  

    # spline = interp.interp2d( x_space,y_space,J_use.transpose().ravel() ,kind = 'cubic' )   
    spline = interp.interp2d( x_space,y_space,J_use.transpose().ravel() ,kind = 'linear' )  # works 

    for j in range(len(x_space)):
        for k in range(len(y_space)): 
            yi = np.array( [X[k,j] , Y[k,j]] ) 
            Ji = J_use[k,j ]

            dE_0 =  sp.compute_dE(yi[0],yi[1])
            cost_new_place = np.zeros( np.shape(u_opts) )   

            dE_n = np.zeros( np.shape(u_opts) )   
            for jj, u_c in enumerate(u_opts, start=0):  
                #----------------solve simulation 
                y_n  = odeint(  sp.pendulum_ode, yi,  tU, args=(u_c,)  )[1]    # ode solver 
                y_n[0] = sp.wrap2periodic(y_n[0],2*np.pi, 0 )                  # wrap theta to range of -pi to pi 

                # find cost of the step
                J_n  = sp.calc_costToGo(yi,u_c, Q,R )  * dtU

                # find the effective change of the step
                dE_n[jj] =  sp.compute_dE(y_n[0],y_n[1])

                # compute cost at new step
                cost_new_place[jj] = spline( y_n[0],y_n[1]  )   + J_n

            # compare costs and find which control action is cheapest
            ind_low = np.argmin(cost_new_place)  
            U[k,j] = u_opts[ind_low]  
            Eff[k,j] = dE_n[ind_low] 
    return U

# %%
 

#---------two IC's  -------   
# y0 = np.array( [[ np.pi-0.6, np.sqrt(- 2*g*(1 +  np.cos(np.pi-0.6)) )]    ])     

# theta = np.pi - 0.6
# dTheta = np.sqrt( -2*g - 2*g*np.cos(theta) ) 
# n_theta  = 1
# one0 = np.ones( (n_theta,3))  
# U0 = np.ones( (n_theta,1)) 
# IC0 = np.vstack( (np.column_stack( (theta,dTheta,one0,U0)   ) , 
#                 np.column_stack( (-theta,-dTheta,one0,U0)   ) )  )   

# #---------------------array of  ICs ----------------------------
n_theta = 200
theta = np.linspace(-np.pi,np.pi, n_theta,endpoint=False)
dTheta = np.sqrt( -2*g - 2*g*np.cos(theta) ) 
one0 = np.ones( (n_theta,3)) 
U0 = np.ones( (n_theta,1)) 

IC0 = np.vstack( (np.column_stack( (theta,dTheta,one0,U0)   ) , 
                np.column_stack( (-theta,-dTheta,one0,U0)   ) )  )

# %%
# initialize point matrix 
point_Mat = np.zeros(( n_points ,6))  
counter = len(IC0)  
point_Mat[:counter] = IC0   

tSave = t_start 
meta_counter = 1
time_sign = -1

for j in range(n_steps):  

    parent_bool = (  point_Mat[:,3]  == 1) &  (point_Mat[:,4]  == 1 )  
    elder_bool = (point_Mat[:,4]  == 1 )  
    subMat = point_Mat[parent_bool,:]  
    
    tNow = time.time()
    delT  = tNow-tSave 
    tSave = tNow 
    print( 'step: ' + str(j) + ', runtime: ' + str( round(tNow-t_start,1) ) + ' sec' + 
          ', dT: ' +  str( round(delT,1) ) + ' sec'  +   ', n_parents: '+str(np.sum(parent_bool ) ) + 
                ', n_elder: '+str(np.sum(elder_bool ))        )    
        
    newest_parent = counter
    for j in range( len(subMat) ):
        Ji = subMat[j,2] 
        yi = subMat[j,[0,1]]
        
        
        dt = dt_set/2+dt_set*np.random.rand(1)[0];  
        t = np.linspace(0,dt,2) # ---time step per simulation ------  
        rad = dt/3
 

        for u_c in u_opts:
            #-------solve ODE --------------------------------------
            yn = odeint(  sp.pendulum_ode, yi,  t, args=(u_c,time_sign,)  ) [1]    # ode solver 
            
            
            dist = np.sqrt( np.sum( (yi-yn)**2 ) )/3
            if dist < rad:
                rad = dist
            
            yn[0] = sp.wrap2periodic( yn[0] )
            Jn = sp.calc_costToGo(yi,u_c, Q,R )*dt + Ji 
            #---------------------------------------------    
            
            dist = np.sqrt(  (point_Mat[:,0] - yn[0] )**2 + (point_Mat[:,1] - yn[1] )**2  ) 
            overlap_bool = dist < rad 
            in_range = np.abs(yn[1]) < max_velocity
            
            # save point if: 
            if (len( point_Mat[overlap_bool,2]) == 0) & in_range:     # empty space found
                point_Mat[counter,:] = np.array([yn[0], yn[1],Jn,1,1,u_c]) 
                counter = counter + 1
            elif np.all( Jn < point_Mat[overlap_bool,2] ) & in_range : # cheapest in the neighborhood 
                point_Mat[counter,:] = np.array([yn[0], yn[1],Jn,1,1,u_c])  
                point_Mat[overlap_bool,4] = 0 # turn off defeated points
                counter = counter + 1  
                
    if intermediate_plotting: 
        f, axs = plt.subplots(1,1,figsize=(10,5) )   
         
        axs.scatter( point_Mat[elder_bool,0], point_Mat[elder_bool,1] ,1 ,'g') 
        axs.scatter( point_Mat[parent_bool,0], point_Mat[parent_bool,1] ,1 ,'r') 
        axs.scatter( point_Mat[newest_parent:counter,0], point_Mat[newest_parent:counter,1] ,1 ,'b') 
        
        set_ax_lim(axs) 
        phd.homoclinic_plot( axs )
        plt.show()
         
    # turn off parent activity for point 
    point_Mat[parent_bool,3] = 0
    
    elder_bool = (point_Mat[:,4]  == 1 )  
    if counter > meta_counter*10000:
        print('Matrix trimming')
        meta_counter = meta_counter +1 
        tempMat = point_Mat[elder_bool,:]
         
        counter = np.shape(tempMat)[0]  
        point_Mat = np.zeros((n_points ,6))
        point_Mat[:counter,:] = tempMat
 
elder_bool = (point_Mat[:,4]  == 1 )    
meta_counter = meta_counter +1
tempMat = point_Mat[elder_bool,:]
 
counter = np.shape(tempMat)[0] 

point_Mat = np.zeros((n_points ,6))
point_Mat[:counter,:] = tempMat
elder_bool = (point_Mat[:,4]  == 1 )    


grid_raw = griddata( point_Mat[elder_bool,:2] ,   point_Mat[elder_bool,2], (X, Y), method='linear') 

J_raw, J_raw_log = sp.matrix_fillnan(grid_raw)
# Out:
# step: 0, runtime: 0.1 sec, dT: 0.1 sec, n_parents: 400, n_elder: 400
# step: 1, runtime: 24.1 sec, dT: 23.9 sec, n_parents: 939, n_elder: 1339
# step: 2, runtime: 76.6 sec, dT: 52.5 sec, n_parents: 2141, n_elder: 3396
# step: 3, runtime: 184.8 sec, dT: 108.1 sec, n_parents: 4165, n_elder: 7230
# Matrix trimming
# step: 4, runtime: 375.8 sec, dT: 191.0 sec, n_parents: 6597, n_elder: 12843
# Matrix trimming
# step: 5, runtime: 667.9 sec, dT: 292.1 sec, n_parents: 8979, n_elder: 19802
# Matrix trimming
# step: 6, runtime: 1063.2 sec, dT: 395.3 sec, n_parents: 11101, n_elder: 27436
# Matrix trimming
# step: 7, runtime: 1551.3 sec, dT: 488.1 sec, n_parents: 12777, n_elder: 35531
# Matrix trimming
# step: 8, runtime: 2115.6 sec, dT: 564.3 sec, n_parents: 14217, n_elder: 43745
# Matrix trimming
# step: 9, runtime: 2745.1 sec, dT: 629.5 sec, n_parents: 15128, n_elder: 51603
# Matrix trimming
# step: 10, runtime: 3415.6 sec, dT: 670.6 sec, n_parents: 15875, n_elder: 59335
# Matrix trimming
# step: 11, runtime: 4118.7 sec, dT: 703.0 sec, n_parents: 16692, n_elder: 66962
# step: 12, runtime: 4867.3 sec, dT: 748.7 sec, n_parents: 17361, n_elder: 74491
# Matrix trimming
# step: 13, runtime: 5645.4 sec, dT: 778.1 sec, n_parents: 17449, n_elder: 81371
# Matrix trimming
# step: 14, runtime: 6423.4 sec, dT: 778.0 sec, n_parents: 18360, n_elder: 88459
# Matrix trimming
# step: 15, runtime: 7241.3 sec, dT: 817.9 sec, n_parents: 18958, n_elder: 95647
# Matrix trimming
# step: 16, runtime: 8088.5 sec, dT: 847.2 sec, n_parents: 19575, n_elder: 102720
# step: 17, runtime: 8964.3 sec, dT: 875.8 sec, n_parents: 19937, n_elder: 109632
# Matrix trimming
# step: 18, runtime: 9903.2 sec, dT: 938.8 sec, n_parents: 19606, n_elder: 115719
# Matrix trimming
# step: 19, runtime: 10785.2 sec, dT: 882.1 sec, n_parents: 20149, n_elder: 122477
# step: 20, runtime: 11690.9 sec, dT: 905.7 sec, n_parents: 20617, n_elder: 129321
# Matrix trimming
# step: 21, runtime: 12624.9 sec, dT: 934.0 sec, n_parents: 20112, n_elder: 135316
# Matrix trimming
# step: 22, runtime: 13530.6 sec, dT: 905.7 sec, n_parents: 20649, n_elder: 141873
# step: 23, runtime: 14459.4 sec, dT: 928.8 sec, n_parents: 21187, n_elder: 148541
# Matrix trimming
# step: 24, runtime: 15420.4 sec, dT: 961.0 sec, n_parents: 20452, n_elder: 153941
# step: 25, runtime: 16340.2 sec, dT: 919.8 sec, n_parents: 21406, n_elder: 160598
# Matrix trimming
# step: 26, runtime: 17310.7 sec, dT: 970.5 sec, n_parents: 20893, n_elder: 166201
# Matrix trimming
# step: 27, runtime: 18254.3 sec, dT: 943.6 sec, n_parents: 21627, n_elder: 172412
# step: 28, runtime: 19231.9 sec, dT: 977.5 sec, n_parents: 22344, n_elder: 178590
# Matrix trimming
# step: 29, runtime: 20245.8 sec, dT: 1013.9 sec, n_parents: 21871, n_elder: 183821
# Matrix trimming
# step: 30, runtime: 21277.6 sec, dT: 1031.8 sec, n_parents: 22741, n_elder: 189710
# step: 31, runtime: 22309.8 sec, dT: 1032.2 sec, n_parents: 22986, n_elder: 195414
# Matrix trimming
# step: 32, runtime: 23356.1 sec, dT: 1046.4 sec, n_parents: 21777, n_elder: 199573
# step: 33, runtime: 24340.1 sec, dT: 983.9 sec, n_parents: 21746, n_elder: 203917
# Matrix trimming
# step: 34, runtime: 25328.0 sec, dT: 988.0 sec, n_parents: 20104, n_elder: 206799
# step: 35, runtime: 26238.1 sec, dT: 910.0 sec, n_parents: 20004, n_elder: 210422
# Matrix trimming
# step: 36, runtime: 27158.7 sec, dT: 920.6 sec, n_parents: 18532, n_elder: 212892
# step: 37, runtime: 27998.7 sec, dT: 839.9 sec, n_parents: 18304, n_elder: 215738
# Matrix trimming
# step: 38, runtime: 28832.3 sec, dT: 833.7 sec, n_parents: 16903, n_elder: 218056
# step: 39, runtime: 29599.5 sec, dT: 767.2 sec, n_parents: 16601, n_elder: 220733
# step: 40, runtime: 30356.6 sec, dT: 757.1 sec, n_parents: 15361, n_elder: 222787
# Matrix trimming
# step: 41, runtime: 31061.5 sec, dT: 704.9 sec, n_parents: 13858, n_elder: 224136
# step: 42, runtime: 31690.8 sec, dT: 629.3 sec, n_parents: 13807, n_elder: 225924
# step: 43, runtime: 32319.5 sec, dT: 628.7 sec, n_parents: 12917, n_elder: 227360
# step: 44, runtime: 32912.6 sec, dT: 593.1 sec, n_parents: 11512, n_elder: 228092
# Matrix trimming
# step: 45, runtime: 33441.0 sec, dT: 528.4 sec, n_parents: 10482, n_elder: 228720
# step: 46, runtime: 33917.4 sec, dT: 476.4 sec, n_parents: 10645, n_elder: 230197
# step: 47, runtime: 34539.0 sec, dT: 621.6 sec, n_parents: 9908, n_elder: 231191
# step: 48, runtime: 35127.5 sec, dT: 588.5 sec, n_parents: 8891, n_elder: 231969
# step: 49, runtime: 35581.8 sec, dT: 454.3 sec, n_parents: 8288, n_elder: 232453
# step: 50, runtime: 36008.1 sec, dT: 426.3 sec, n_parents: 7646, n_elder: 232547
# Matrix trimming
# step: 51, runtime: 36358.7 sec, dT: 350.6 sec, n_parents: 7355, n_elder: 233068
# step: 52, runtime: 36693.3 sec, dT: 334.6 sec, n_parents: 7558, n_elder: 233928
# step: 53, runtime: 37038.9 sec, dT: 345.6 sec, n_parents: 7392, n_elder: 234918
# step: 54, runtime: 37376.2 sec, dT: 337.2 sec, n_parents: 6865, n_elder: 235717
# step: 55, runtime: 37720.3 sec, dT: 344.1 sec, n_parents: 6511, n_elder: 236491
# step: 56, runtime: 38063.7 sec, dT: 343.4 sec, n_parents: 6108, n_elder: 237107
# step: 57, runtime: 38391.3 sec, dT: 327.7 sec, n_parents: 5752, n_elder: 237627
# step: 58, runtime: 38713.2 sec, dT: 321.9 sec, n_parents: 5143, n_elder: 238100
# step: 59, runtime: 38965.7 sec, dT: 252.5 sec, n_parents: 4658, n_elder: 238451
# Matrix trimming
# step: 60, runtime: 39182.9 sec, dT: 217.2 sec, n_parents: 4273, n_elder: 238717
# step: 61, runtime: 39378.6 sec, dT: 195.7 sec, n_parents: 4411, n_elder: 239490
# step: 62, runtime: 39592.3 sec, dT: 213.7 sec, n_parents: 4120, n_elder: 239966
# step: 63, runtime: 39841.8 sec, dT: 249.5 sec, n_parents: 3841, n_elder: 240259
# step: 64, runtime: 40069.6 sec, dT: 227.7 sec, n_parents: 3487, n_elder: 240673
# step: 65, runtime: 40249.3 sec, dT: 179.7 sec, n_parents: 3227, n_elder: 241065
# step: 66, runtime: 40430.5 sec, dT: 181.2 sec, n_parents: 2905, n_elder: 241392
# step: 67, runtime: 40610.0 sec, dT: 179.5 sec, n_parents: 2613, n_elder: 241572
# step: 68, runtime: 40798.2 sec, dT: 188.2 sec, n_parents: 2444, n_elder: 241643
# step: 69, runtime: 40980.8 sec, dT: 182.6 sec, n_parents: 2267, n_elder: 241538
# step: 70, runtime: 41135.9 sec, dT: 155.1 sec, n_parents: 2067, n_elder: 241360
# step: 71, runtime: 41276.8 sec, dT: 140.9 sec, n_parents: 2004, n_elder: 241284
# step: 72, runtime: 41422.4 sec, dT: 145.6 sec, n_parents: 1895, n_elder: 241348
# step: 73, runtime: 41552.9 sec, dT: 130.5 sec, n_parents: 1761, n_elder: 241434
# step: 74, runtime: 41674.6 sec, dT: 121.7 sec, n_parents: 1641, n_elder: 241534
# step: 75, runtime: 41784.9 sec, dT: 110.3 sec, n_parents: 1508, n_elder: 241744
# step: 76, runtime: 41862.5 sec, dT: 77.6 sec, n_parents: 1358, n_elder: 241928
# step: 77, runtime: 41926.0 sec, dT: 63.5 sec, n_parents: 1217, n_elder: 242108
# step: 78, runtime: 41982.4 sec, dT: 56.4 sec, n_parents: 1086, n_elder: 242241
# step: 79, runtime: 42033.8 sec, dT: 51.4 sec, n_parents: 961, n_elder: 242375
# step: 80, runtime: 42078.8 sec, dT: 45.0 sec, n_parents: 845, n_elder: 242490
# step: 81, runtime: 42117.8 sec, dT: 39.1 sec, n_parents: 750, n_elder: 242647
# step: 82, runtime: 42153.1 sec, dT: 35.2 sec, n_parents: 646, n_elder: 242745
# step: 83, runtime: 42183.0 sec, dT: 29.9 sec, n_parents: 572, n_elder: 242802
# step: 84, runtime: 42210.5 sec, dT: 27.5 sec, n_parents: 545, n_elder: 242846
# step: 85, runtime: 42235.9 sec, dT: 25.4 sec, n_parents: 507, n_elder: 242859
# step: 86, runtime: 42262.9 sec, dT: 27.1 sec, n_parents: 452, n_elder: 242899
# step: 87, runtime: 42298.4 sec, dT: 35.5 sec, n_parents: 389, n_elder: 242957
# step: 88, runtime: 42321.3 sec, dT: 22.9 sec, n_parents: 332, n_elder: 242878
# step: 89, runtime: 42341.0 sec, dT: 19.7 sec, n_parents: 264, n_elder: 242852
# step: 90, runtime: 42359.4 sec, dT: 18.4 sec, n_parents: 216, n_elder: 242825
# step: 91, runtime: 42370.4 sec, dT: 11.0 sec, n_parents: 220, n_elder: 242831
# step: 92, runtime: 42381.3 sec, dT: 11.0 sec, n_parents: 178, n_elder: 242834
# step: 93, runtime: 42390.1 sec, dT: 8.7 sec, n_parents: 175, n_elder: 242869
# step: 94, runtime: 42398.8 sec, dT: 8.7 sec, n_parents: 168, n_elder: 242886
# step: 95, runtime: 42408.9 sec, dT: 10.1 sec, n_parents: 172, n_elder: 242922
# step: 96, runtime: 42419.3 sec, dT: 10.4 sec, n_parents: 179, n_elder: 242928
# step: 97, runtime: 42428.7 sec, dT: 9.3 sec, n_parents: 166, n_elder: 242937
# step: 98, runtime: 42438.0 sec, dT: 9.4 sec, n_parents: 151, n_elder: 243011
# step: 99, runtime: 42445.4 sec, dT: 7.4 sec, n_parents: 147, n_elder: 243070
# step: 100, runtime: 42452.9 sec, dT: 7.5 sec, n_parents: 114, n_elder: 243116
# step: 101, runtime: 42458.7 sec, dT: 5.8 sec, n_parents: 101, n_elder: 243152
# step: 102, runtime: 42463.6 sec, dT: 4.9 sec, n_parents: 94, n_elder: 243190
# step: 103, runtime: 42468.1 sec, dT: 4.5 sec, n_parents: 82, n_elder: 243235
# step: 104, runtime: 42472.0 sec, dT: 3.9 sec, n_parents: 80, n_elder: 243264
# step: 105, runtime: 42475.7 sec, dT: 3.7 sec, n_parents: 72, n_elder: 243280
# step: 106, runtime: 42479.0 sec, dT: 3.4 sec, n_parents: 61, n_elder: 243312
# step: 107, runtime: 42481.9 sec, dT: 2.9 sec, n_parents: 55, n_elder: 243343
# step: 108, runtime: 42484.5 sec, dT: 2.6 sec, n_parents: 57, n_elder: 243373
# step: 109, runtime: 42487.2 sec, dT: 2.7 sec, n_parents: 49, n_elder: 243404
# step: 110, runtime: 42489.5 sec, dT: 2.3 sec, n_parents: 35, n_elder: 243422
# step: 111, runtime: 42491.1 sec, dT: 1.6 sec, n_parents: 30, n_elder: 243436
# step: 112, runtime: 42492.5 sec, dT: 1.4 sec, n_parents: 21, n_elder: 243451
# step: 113, runtime: 42493.5 sec, dT: 1.0 sec, n_parents: 16, n_elder: 243460
# step: 114, runtime: 42494.3 sec, dT: 0.8 sec, n_parents: 15, n_elder: 243471
# step: 115, runtime: 42495.0 sec, dT: 0.7 sec, n_parents: 12, n_elder: 243483
# step: 116, runtime: 42495.6 sec, dT: 0.6 sec, n_parents: 13, n_elder: 243495
# step: 117, runtime: 42496.2 sec, dT: 0.6 sec, n_parents: 14, n_elder: 243501
# step: 118, runtime: 42496.9 sec, dT: 0.7 sec, n_parents: 16, n_elder: 243509
# step: 119, runtime: 42497.7 sec, dT: 0.8 sec, n_parents: 16, n_elder: 243520
# step: 120, runtime: 42498.5 sec, dT: 0.8 sec, n_parents: 14, n_elder: 243530
# step: 121, runtime: 42499.2 sec, dT: 0.7 sec, n_parents: 11, n_elder: 243536
# step: 122, runtime: 42499.7 sec, dT: 0.5 sec, n_parents: 11, n_elder: 243545
# step: 123, runtime: 42500.2 sec, dT: 0.5 sec, n_parents: 12, n_elder: 243545
# step: 124, runtime: 42500.8 sec, dT: 0.6 sec, n_parents: 15, n_elder: 243552
# step: 125, runtime: 42501.5 sec, dT: 0.7 sec, n_parents: 17, n_elder: 243555
# step: 126, runtime: 42502.4 sec, dT: 0.8 sec, n_parents: 15, n_elder: 243564
# step: 127, runtime: 42503.1 sec, dT: 0.7 sec, n_parents: 14, n_elder: 243577
# step: 128, runtime: 42503.7 sec, dT: 0.7 sec, n_parents: 14, n_elder: 243587
# step: 129, runtime: 42504.4 sec, dT: 0.7 sec, n_parents: 11, n_elder: 243595
# step: 130, runtime: 42505.0 sec, dT: 0.5 sec, n_parents: 15, n_elder: 243603
# step: 131, runtime: 42505.7 sec, dT: 0.7 sec, n_parents: 18, n_elder: 243603
# step: 132, runtime: 42506.5 sec, dT: 0.9 sec, n_parents: 15, n_elder: 243609
# step: 133, runtime: 42507.3 sec, dT: 0.8 sec, n_parents: 19, n_elder: 243618
# step: 134, runtime: 42508.3 sec, dT: 1.0 sec, n_parents: 19, n_elder: 243608
# step: 135, runtime: 42509.3 sec, dT: 1.0 sec, n_parents: 19, n_elder: 243619
# step: 136, runtime: 42510.2 sec, dT: 0.9 sec, n_parents: 21, n_elder: 243629
# step: 137, runtime: 42511.4 sec, dT: 1.1 sec, n_parents: 25, n_elder: 243635
# step: 138, runtime: 42512.6 sec, dT: 1.2 sec, n_parents: 22, n_elder: 243643
# step: 139, runtime: 42513.6 sec, dT: 1.1 sec, n_parents: 18, n_elder: 243642

# %%
elder_bool = (point_Mat[:,4]  == 1 )    
grid_U = griddata( point_Mat[elder_bool,:2] ,   point_Mat[elder_bool,5], (X, Y), method='linear') 


f, axs = plt.subplots(1,1 ,figsize=(8,5) )    
axs.pcolor(X,Y, grid_U  )

# %%
# yn

# %%
n_slices = 201
intermediate_plotting = False 
angle_range = np.linspace(-np.pi,np.pi,n_slices)

d_angle = angle_range[1]-angle_range[0]
overlap = 1

elder_bool = (point_Mat[:,4]  == 1 )

pos_angle = np.expand_dims( np.arctan2( point_Mat[elder_bool,1] , point_Mat[elder_bool,0]) ,  axis=1)
pos_E = np.expand_dims( sp.compute_dE( point_Mat[elder_bool,0], point_Mat[elder_bool,1] ),  axis=1)
 
data = np.concatenate( ( point_Mat[elder_bool,:] ,pos_E ,pos_angle ) ,axis=1 )
 
keepList = [] 

for j in range(len(angle_range)):    
    
    low_lim = angle_range[j]-(d_angle/2)*(1+overlap)
    high_lim = angle_range[j]+(d_angle/2)*(1+overlap)
    in_range = (pos_angle>low_lim) & (pos_angle<high_lim)
 
    tempData = data[in_range[:,0],:]
    ind_sorted = np.argsort( tempData[:,6])
    tempData2 = tempData[ind_sorted,:] 
    
    minV= np.min(tempData2[:,2])
    minI= np.argmin(tempData2[:,2])
    
    minJList = []
    minJListUp = [] 
    minJList.append(tempData2[0]) 
    minJListUp.append(tempData2[-1]) 
     
    for k in range(len(tempData2)):
        if tempData2[k,2] < minJList[-1][2]:
            minJList.append(tempData2[k,:]) 
            keepList.append(tempData2[k,:]) 
    for k in reversed(range(len(tempData2)) ):
        if tempData2[k,2] < minJListUp[-1][2]:
            minJListUp.append(tempData2[k,:]) 
            keepList.append(tempData2[k,:])  
    minMat = np.asarray(minJList) 
    minMatUp = np.asarray(minJListUp)  
    
    if intermediate_plotting == True: 
        f, axs = plt.subplots(1,1 ,figsize=(8,5) )    
        axs.scatter( tempData2[minI,6],  tempData2[minI,2] ,100, 'r')   
        axs.scatter( tempData2[:,6] , tempData2[:,2] ,1,'g')
        axs.scatter( minMat[:,6] , minMat[:,2] ,1,'b')
        axs.scatter( minMatUp[:,6] , minMatUp[:,2] ,1,'b')

        axs.set_xlim([-20,20]) 
        axs.set_ylim([-50,3000]) 
        axs.set_xlabel('Total energy')
        axs.set_ylabel('Cost J') 
     
point_Mat_filt = np.asarray(keepList)

# %%
f, axs = plt.subplots(1,1 ,figsize=(8,5) )    
axs.scatter( point_Mat_filt[:,0], point_Mat_filt[:,1] , 1 )

# %%
# point_Mat_filt = np.asarray(keepList)  

elder_bool_filt = (point_Mat_filt[:,4]  == 1 )    
grid_U = griddata( point_Mat_filt[elder_bool_filt,:2] ,   point_Mat_filt[elder_bool_filt,5], (X, Y), method='linear') 


f, axs = plt.subplots(1,1 ,figsize=(8,5) )    
axs.pcolor(X,Y, grid_U  )

# %%
filter_on = True


if filter_on:
    elder_bool = (point_Mat_filt[:,4]  == 1 )
    grid_z1 = griddata( point_Mat_filt[elder_bool,:2] ,   point_Mat_filt[elder_bool,2], (X, Y), method='linear') 
else:
    grid_z1 = grid_raw

J_filter, J_filter_log = sp.matrix_fillnan(grid_z1)

# %%
print('time to run so far: ' + str(round(time.time()-t_start,1)) + ' seconds')
# Out:
# time to run so far: 42530.3 seconds

# %%
# combine griddata  
point_Mat_elder = point_Mat_filt 

point_Mat_elder_2 = point_Mat_elder.copy()
point_Mat_elder_2[:,0] = point_Mat_elder[:,0]-2*np.pi  

point_Mat_elder_3 = point_Mat_elder.copy()
point_Mat_elder_3[:,0] = point_Mat_elder[:,0]+2*np.pi  

point_Mat_combined = np.vstack( (point_Mat_elder, point_Mat_elder_2,point_Mat_elder_3)  )
point_Mat_combined[:,7]= np.arctan2( point_Mat_combined[:,1], point_Mat_combined[:,0]  )

# %%
elder_bool = (point_Mat_combined[:,4]  == 1 )
grid_z1 = griddata( point_Mat_combined[elder_bool,:2] ,   point_Mat_combined[elder_bool,2], (X, Y), method='linear') 

J_combined, J_combined_log = sp.matrix_fillnan(grid_z1)

# %%
# plotting parameters 
max_J = 7
plt.style.use('latex_scientificPaperStyle.mplstyle')
col = sns.color_palette("hls", 5)  
colorsList = [col[2],np.array([255,255,200])/255,col[3]]  
plt.rc('font', family='serif')
rc('text', usetex=True) 
contr = matplotlib.colors.ListedColormap(colorsList)

# %%
# plot raw points, contains unoptimal points still 

f, axs = plt.subplots(1,2 ,figsize=(20,8) )   

# axs[0].pcolor(X,Y, J_log , cmap='BuGn' )      
axs[0].pcolor(X,Y, J_raw_log,vmax = max_J , cmap='BuGn' )      
axs[0] = phd.homoclinic_plot(axs[0]) 
     
# figure style 
axs[0].xaxis.set_major_locator(plt.MultipleLocator(np.pi )) 
axs[0].xaxis.set_major_formatter(plt.FuncFormatter(phd.multiple_formatter()))  
# axs[0].set_ylim([-12,12])
set_ax_lim(axs[1])
axs[0].set_xlabel(r' $\theta$ (rad)',fontsize = 16)
axs[0].set_ylabel(r"$\dot{\theta}$"  "\n"  "(rad/s)",fontsize = 16,rotation = 0) 
axs[0].set_title('Cost J',fontsize = 16) 
axs[0].set_ylim([-12,12])  
 
# U_comp = compute_U( J_smooth, x_space, y_space, X,Y, u_opts, tU, Q,R) 
U_comp = compute_U( J_raw, x_space, y_space, X,Y, u_opts, tU, Q,R) 
axs[1].pcolor(X,Y, U_comp , cmap= contr )   

axs[1] = phd.homoclinic_plot(axs[1])
# axs[1].set_ylim([-12,12])
set_ax_lim(axs[1])
axs[1].set_xlabel(r' $\theta$ (rad)',fontsize = 16)
axs[1].set_ylabel(r"$\dot{\theta}$"  "\n"  "(rad/s)",fontsize = 16,rotation = 0)
axs[1].text(-1,10,'U = negative',color = 'white', fontsize = 24)
axs[1].text(-2,-.5,'U = 0',color = 'black', fontsize = 24 )
axs[1].text(1,-.5,'U = 0',color = 'black', fontsize = 24)
axs[1].text(-0.5,3,'U = positive',color = 'white', fontsize = 12)
axs[1].text(-0.5,-3.6,'U = negative',color = 'white', fontsize = 12)
axs[1].text(-1,-11,'U = positive',color = 'white', fontsize = 24)
axs[1].xaxis.set_major_locator(plt.MultipleLocator(np.pi )) 
axs[1].xaxis.set_major_formatter(plt.FuncFormatter(phd.multiple_formatter()))  
axs[1].set_title('Control policy',fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Control policy')

# %%
# plot radially filtered points 
f, axs = plt.subplots(1,2 ,figsize=(20,8) )   

# axs[0].pcolor(X,Y, J_log , cmap='BuGn' )      
axs[0].pcolor(X,Y, J_combined_log,vmax = max_J , cmap='BuGn' )      
axs[0] = phd.homoclinic_plot(axs[0]) 
     
# figure style 
axs[0].xaxis.set_major_locator(plt.MultipleLocator(np.pi )) 
axs[0].xaxis.set_major_formatter(plt.FuncFormatter(phd.multiple_formatter()))  
# axs[0].set_ylim([-12,12])
set_ax_lim(axs[1])
axs[0].set_xlabel(r' $\theta$ (rad)',fontsize = 16)
axs[0].set_ylabel(r"$\dot{\theta}$"  "\n"  "(rad/s)",fontsize = 16,rotation = 0) 
axs[0].set_title('Cost J',fontsize = 16) 
axs[0].set_ylim([-12,12])  
 
U_comp = compute_U( J_combined, x_space, y_space, X,Y, u_opts, tU, Q,R) 
axs[1].pcolor(X,Y, U_comp , cmap= contr )   

axs[1] = phd.homoclinic_plot(axs[1])
# axs[1].set_ylim([-12,12])
set_ax_lim(axs[1])
axs[1].set_xlabel(r' $\theta$ (rad)',fontsize = 16)
axs[1].set_ylabel(r"$\dot{\theta}$"  "\n"  "(rad/s)",fontsize = 16,rotation = 0)
axs[1].text(-1,10,'U = negative',color = 'white', fontsize = 24)
axs[1].text(-2,-.5,'U = 0',color = 'black', fontsize = 24 )
axs[1].text(1,-.5,'U = 0',color = 'black', fontsize = 24)
axs[1].text(-0.5,3,'U = positive',color = 'white', fontsize = 12)
axs[1].text(-0.5,-3.6,'U = negative',color = 'white', fontsize = 12)
axs[1].text(-1,-11,'U = positive',color = 'white', fontsize = 24)
axs[1].xaxis.set_major_locator(plt.MultipleLocator(np.pi )) 
axs[1].xaxis.set_major_formatter(plt.FuncFormatter(phd.multiple_formatter()))  
axs[1].set_title('Control policy',fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Control policy')

# %%
# ----------------------------------- turn filter into J  
Gauss_width = 0.5 
 
J_smooth_raw = ndimage.gaussian_filter(J_combined, sigma=Gauss_width, order=0) 
J_smooth, J_smooth_log = sp.matrix_fillnan(J_smooth_raw)  




# plot plot radially filtered and gaussian smoothened points
f, axs = plt.subplots(1,2 ,figsize=(20,8) )   
 
axs[0].pcolor(X,Y, J_smooth_log,vmax = max_J , cmap='BuGn' )      
axs[0] = phd.homoclinic_plot(axs[0]) 
     
# figure style 
axs[0].xaxis.set_major_locator(plt.MultipleLocator(np.pi )) 
axs[0].xaxis.set_major_formatter(plt.FuncFormatter(phd.multiple_formatter()))  
# axs[0].set_ylim([-12,12])
set_ax_lim(axs[0])
axs[0].set_xlabel(r' $\theta$ (rad)',fontsize = 16)
axs[0].set_ylabel(r"$\dot{\theta}$"  "\n"  "(rad/s)",fontsize = 16,rotation = 0) 
axs[0].set_title('Cost J',fontsize = 16) 
axs[0].set_ylim([-12,12])  
  
U_comp = compute_U( J_smooth, x_space, y_space, X,Y, u_opts, tU, Q,R) 
axs[1].pcolor(X,Y, U_comp , cmap= contr )   

axs[1] = phd.homoclinic_plot(axs[1])
# axs[1].set_ylim([-12,12])
set_ax_lim(axs[1])
axs[1].set_xlabel(r' $\theta$ (rad)',fontsize = 16)
axs[1].set_ylabel(r"$\dot{\theta}$"  "\n"  "(rad/s)",fontsize = 16,rotation = 0)
axs[1].text(-1,10,'U = negative',color = 'white', fontsize = 24)
axs[1].text(-2,-.5,'U = 0',color = 'black', fontsize = 24 )
axs[1].text(1,-.5,'U = 0',color = 'black', fontsize = 24)
axs[1].text(-0.5,3,'U = positive',color = 'white', fontsize = 12)
axs[1].text(-0.5,-3.6,'U = negative',color = 'white', fontsize = 12)
axs[1].text(-1,-11,'U = positive',color = 'white', fontsize = 24)
axs[1].xaxis.set_major_locator(plt.MultipleLocator(np.pi )) 
axs[1].xaxis.set_major_formatter(plt.FuncFormatter(phd.multiple_formatter()))  
axs[1].set_title('Control policy',fontsize = 16)  

print('time to run so far: ' + str(round(time.time()-t_start,1)) + ' seconds')
# Out:
# time to run so far: 42577.6 seconds

# %%
# ----------------------------------- turn filter into J  
Gauss_width = 1   

J_smooth_raw = ndimage.gaussian_filter(J_combined, sigma=Gauss_width, order=0) 
J_smooth, J_smooth_log = sp.matrix_fillnan(J_smooth_raw)  




# plot plot radially filtered and gaussian smoothened points
f, axs = plt.subplots(1,2 ,figsize=(20,8) )   
 
axs[0].pcolor(X,Y, J_smooth_log,vmax = max_J , cmap='BuGn' )      
axs[0] = phd.homoclinic_plot(axs[0]) 
     
# figure style 
axs[0].xaxis.set_major_locator(plt.MultipleLocator(np.pi )) 
axs[0].xaxis.set_major_formatter(plt.FuncFormatter(phd.multiple_formatter()))  
# axs[0].set_ylim([-12,12])
set_ax_lim(axs[0])
axs[0].set_xlabel(r' $\theta$ (rad)',fontsize = 16)
axs[0].set_ylabel(r"$\dot{\theta}$"  "\n"  "(rad/s)",fontsize = 16,rotation = 0) 
axs[0].set_title('Cost J',fontsize = 16) 
axs[0].set_ylim([-12,12])  
  
U_comp = compute_U( J_smooth, x_space, y_space, X,Y, u_opts, tU, Q,R) 
axs[1].pcolor(X,Y, U_comp , cmap= contr )   

axs[1] = phd.homoclinic_plot(axs[1])
# axs[1].set_ylim([-12,12])
set_ax_lim(axs[1])
axs[1].set_xlabel(r' $\theta$ (rad)',fontsize = 16)
axs[1].set_ylabel(r"$\dot{\theta}$"  "\n"  "(rad/s)",fontsize = 16,rotation = 0)
axs[1].text(-1,10,'U = negative',color = 'white', fontsize = 24)
axs[1].text(-2,-.5,'U = 0',color = 'black', fontsize = 24 )
axs[1].text(1,-.5,'U = 0',color = 'black', fontsize = 24)
axs[1].text(-0.5,3,'U = positive',color = 'white', fontsize = 12)
axs[1].text(-0.5,-3.6,'U = negative',color = 'white', fontsize = 12)
axs[1].text(-1,-11,'U = positive',color = 'white', fontsize = 24)
axs[1].xaxis.set_major_locator(plt.MultipleLocator(np.pi )) 
axs[1].xaxis.set_major_formatter(plt.FuncFormatter(phd.multiple_formatter()))  
axs[1].set_title('Control policy',fontsize = 16)  

print('time to run so far: ' + str(round(time.time()-t_start,1)) + ' seconds')
np.save( 'u_gridfree_highdef_gauss1.npy', (U_comp,X,Y) )
# Out:
# time to run so far: 42776.6 seconds

# %%
# ----------------------------------- turn filter into J  
Gauss_width = 2   

J_smooth_raw = ndimage.gaussian_filter(J_combined, sigma=Gauss_width, order=0) 
J_smooth, J_smooth_log = sp.matrix_fillnan(J_smooth_raw)  
 
# plot plot radially filtered and gaussian smoothened points
f, axs = plt.subplots(1,2 ,figsize=(20,8) )   
 
axs[0].pcolor(X,Y, J_smooth_log,vmax = max_J , cmap='BuGn' )      
axs[0] = phd.homoclinic_plot(axs[0]) 
     
# figure style 
axs[0].xaxis.set_major_locator(plt.MultipleLocator(np.pi )) 
axs[0].xaxis.set_major_formatter(plt.FuncFormatter(phd.multiple_formatter()))  
# axs[0].set_ylim([-12,12])
set_ax_lim(axs[1])
axs[0].set_xlabel(r' $\theta$ (rad)',fontsize = 16)
axs[0].set_ylabel(r"$\dot{\theta}$"  "\n"  "(rad/s)",fontsize = 16,rotation = 0) 
axs[0].set_title('Cost J',fontsize = 16) 
# axs[0].set_ylim([-12,12])  
  
U_comp = compute_U( J_smooth, x_space, y_space, X,Y, u_opts, tU, Q,R) 
pcol= axs[1].pcolor(X,Y, U_comp , cmap= contr )   

axs[1] = phd.homoclinic_plot(axs[1])
# axs[1].set_ylim([-12,12])
set_ax_lim(axs[1])
axs[1].set_xlabel(r' $\theta$ (rad)',fontsize = 16)
axs[1].set_ylabel(r"$\dot{\theta}$"  "\n"  "(rad/s)",fontsize = 16,rotation = 0) 
axs[1].xaxis.set_major_locator(plt.MultipleLocator(np.pi )) 
axs[1].xaxis.set_major_formatter(plt.FuncFormatter(phd.multiple_formatter()))  
axs[1].set_title('Control policy',fontsize = 16)  

 
from mpl_toolkits.axes_grid1.inset_locator import inset_axes 
axins = inset_axes(axs[1],
                   width="5%",  # width = 5% of parent_bbox width
                   height="50%",  # height : 50%
                   loc='lower left',
                   bbox_to_anchor=(1.05, 0.45, 1, 1),
                   bbox_transform=axs[1].transAxes,
                   borderpad=0,
                   ) 

cbar = f.colorbar(pcol, cax=axins , ticks=[-2,0,2] )
cbar.ax.set_yticklabels([-3,0,3])  # vertically oriented colorbar
cbar.ax.set_title('Control U')  

print('time to run so far: ' + str(round(time.time()-t_start,1)) + ' seconds')

np.save( 'u_gridfree_highdef.npy', (U_comp,X,Y) )
# Out:
# time to run so far: 42761.0 seconds
